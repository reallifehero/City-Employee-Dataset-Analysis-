# %% [markdown]
# Data Location: https://data.baltimorecity.gov/City-Government/Baltimore-City-Employee-Salaries-FY2018/biyh-j8tc
#
#
# Descriptions:
#
# The data provides us with the salary of the employees of the City of Baltimore for year 2018.
# I also work for the City of Baltimore. So I’m familiar with content of the dataset.
# The data was discovered from the sources the professor had provided.
# The data is relevant to Data Science because I will be able to mine useful information from it.
# I will visualize the data using graphs and charts.
# There is no documented EDA for this dataset as far as I have seen.
# The data consists of the following information: Name, Job title, Department ID, Description, Hire Date,
# Annual Income, and Gross Salary.
# The dataset has 13682 rows and 7 columns. The data is 5.3 megabytes.

# %% [markdown]
# #DATA ANALYSIS

# %%
import pandas
import numpy as np 
pandas.__version__ #import librabries
# Out:
# '0.25.1'

# %%
city_df = pandas.read_csv('C:\\Users\\nasir\\Desktop\\Data 601\\Week 4\\Baltimore_City_Employee_Salaries_FY2018.csv')
city_df.head() #load the data
# Out:
#                     NAME                       JOBTITLE  DEPTID  \
# 0       Aaron,Patricia G  Facilities/Office Services II  A03031
# 1          Aaron,Petra L     Assistant State's Attorney  A29045
# 2          Abadir,Adam O             Council Technician  A02002
# 3  Abaku,Aigbolosimuan O         Police Officer Trainee  A99416
# 4          Abbeduto,Mack                  Law Clerk SAO  A29017
#
#                            DESCR                 HIRE_DT  ANNUAL_RT     GROSS
# 0       OED-Employment Dev (031)  10/24/1979 12:00:00 AM    60200.0  58480.46
# 1  States Attorneys Office (045)  09/25/2006 12:00:00 AM    81200.0  79220.72
# 2             City Council (002)  12/12/2016 12:00:00 AM    64823.0  57375.31
# 3        Police Department (416)  04/17/2018 12:00:00 AM    50440.0  11881.34
# 4  States Attorneys Office (017)  05/22/2017 12:00:00 AM    38926.0  35138.40

# %%
city_df.columns=['NAME','JOBTITLE','DEPTID','DESCR','HIRE_DT','BASE_PAY','GROSS_EARNING']
city_df.head() #rename columns
# Out:
#                     NAME                       JOBTITLE  DEPTID  \
# 0       Aaron,Patricia G  Facilities/Office Services II  A03031
# 1          Aaron,Petra L     Assistant State's Attorney  A29045
# 2          Abadir,Adam O             Council Technician  A02002
# 3  Abaku,Aigbolosimuan O         Police Officer Trainee  A99416
# 4          Abbeduto,Mack                  Law Clerk SAO  A29017
#
#                            DESCR                 HIRE_DT  BASE_PAY  \
# 0       OED-Employment Dev (031)  10/24/1979 12:00:00 AM   60200.0
# 1  States Attorneys Office (045)  09/25/2006 12:00:00 AM   81200.0
# 2             City Council (002)  12/12/2016 12:00:00 AM   64823.0
# 3        Police Department (416)  04/17/2018 12:00:00 AM   50440.0
# 4  States Attorneys Office (017)  05/22/2017 12:00:00 AM   38926.0
#
#    GROSS_EARNING
# 0       58480.46
# 1       79220.72
# 2       57375.31
# 3       11881.34
# 4       35138.40

# %%
city_df.tail() #bottom 5 datapoints
# Out:
#                        NAME                     JOBTITLE  DEPTID  \
# 13678       Zorzi,Matthew J         Recreation Leader II  A04009
# 13679           Zou,Zhi Fan                 Police Cadet  A99416
# 13680  Zovistoski,Zachary D               Police Officer  A99006
# 13681     Zuhoski,Timothy C       Police Officer Trainee  A99261
# 13682        Zuniga,Linette  Grant Services Specialist I  A65527
#
#                               DESCR                 HIRE_DT  ANNUAL_RT  \
# 13678          R&P-Recreation (009)  07/07/2016 12:00:00 AM    33199.0
# 13679       Police Department (416)  04/11/2018 12:00:00 AM    31388.0
# 13680       Police Department (006)  12/17/2013 12:00:00 AM    64556.0
# 13681       Police Department (261)  01/31/2017 12:00:00 AM    50561.0
# 13682  HLTH-Health Department (527)  10/20/2016 12:00:00 AM    29129.0
#
#           GROSS
# 13678  34888.80
# 13679   7650.19
# 13680  75743.78
# 13681  60078.31
# 13682  22817.57

# %%
city_df.shape #total columns and rows
# Out:
# (13683, 7)

# %%
city_df.info() #column values description
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13683 entries, 0 to 13682
# Data columns (total 7 columns):
# NAME         13683 non-null object
# JOBTITLE     13683 non-null object
# DEPTID       13683 non-null object
# DESCR        13683 non-null object
# HIRE_DT      13680 non-null object
# ANNUAL_RT    13683 non-null float64
# GROSS        13522 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 748.4+ KB

# %% [markdown]
# The datatypes of our features are objects(5) and float64(2). There are no missing values(non-null). There are 13683 entries just like we saw with the shape method.

# %%
city_df.describe() #statistics about data
# Out:
#            ANNUAL_RT          GROSS
# count   13683.000000   13522.000000
# mean    56751.774026   60729.312142
# std     25491.250161   36197.335957
# min      1800.000000       0.000000
# 25%     36399.500000   37509.352500
# 50%     52456.000000   57060.665000
# 75%     73440.000000   81730.975000
# max    250000.000000  250197.500000

# %% [markdown]
# To see statistics on non-numerical features, I explicitly indicated data the type 'object' to see the description.

# %%
city_df.describe(include=['object'])
# Out:
#                  NAME        JOBTITLE  DEPTID                         DESCR  \
# count           13683           13683   13683                         13683
# unique          13472            1012     673                           672
# top     Thomas,Stacey  Police Officer  C90786  R&P-Recreation (part-time) (
# freq                3            1423     230                           330
#
#                        HIRE_DT
# count                    13680
# unique                    4636
# top     06/23/2007 12:00:00 AM
# freq                        78

# %% [markdown]
# For categorial features, we can use the value_counts methods to see the distributions of a column.

# %%
city_df['DEPTID'].value_counts() #department ID counts
# Out:
# C90786    230
# A99416    200
# P04001    174
# P04002    156
# A85301    144
#          ...
# A50210      1
# A99163      1
# A99349      1
# A75         1
# A99197      1
# Name: DEPTID, Length: 673, dtype: int64

# %%
city_df['DESCR'].value_counts() #different departments
# Out:
# R&P-Recreation (part-time) (    330
# TRANS-Crossing Guards (786)     230
# Police Department (416)         200
# General Services (301)          144
# Police Department (386)         119
#                                ...
# DPW-Solid Waste (wkly) (404)      1
# R&P-Administration (004)          1
# TRANS-Traffic (042)               1
# M-R Human Services (001)          1
# FIN-Purchasing                    1
# Name: DESCR, Length: 672, dtype: int64

# %%
city_df.sort_values(by=['DEPTID','DESCR'],
                   ascending=[True, True]).head(10) #sort by department ID and description
# Out:
#                           NAME                       JOBTITLE  DEPTID  \
# 137          Aleshire,Andrew M           Operations Officer I  A01001
# 174             Allen,Carvel T            Executive Assistant  A01001
# 432               Asli,Kenya N         Operations Officer III  A01001
# 538             Bailey,Tanya H  Staff Asst (Elected Official)  A01001
# 563                  Baker,Jay       Operations Assistant III  A01001
# 607              Banks,Kyron A       Legislative/Govt Liaison  A01001
# 639            Barksdale,Dante   Liaison Officer Safe Streets  A01001
# 673          Barnwell,Shakia S             Work Study Student  A01001
# 897  Bennett-Parker,Candisse S       Operations Assistant III  A01001
# 904         Bentley II,James E          Operations Officer II  A01001
#
#                    DESCR                 HIRE_DT  ANNUAL_RT     GROSS
# 137  Mayors Office (001)  12/07/2016 12:00:00 AM    84900.0  83968.15
# ...

# %%
city_df.iloc[280:290] #look up certain data points
# Out:
#                        NAME                      JOBTITLE  DEPTID  \
# 280  Andersen III,William H             Design Planner II  A67002
# 281   Anderson Jr,Kenneth A         Electrical Mechanic I  A49390
# 282   Anderson Jr.,Ronald J                Community Aide  A68004
# 283         Anderson,Andrea                     Ombudsman  A06010
# 284       Anderson,Andrea H                Special Aide I  A31009
# 285        Anderson,Anthony  Water Systems Treatment Supv  A50307
# 286        Anderson,April D               Paramedic EMT-P  A64465
# 287      Anderson,Catherine                Crossing Guard  C90786
# 288        Anderson,Charles           Police Sergeant EID  A99225
# 289      Anderson,Clemmie O                Police Officer  A99261
#
#                              DESCR                 HIRE_DT  ANNUAL_RT  \
# 280       R&P-Administration (002)  04/27/2009 12:00:00 AM    69315.0
# 281           TRANS-Highways (390)  10/14/2014 12:00:00 AM    37543.0
# ...

# %%
city_df.loc[0:9,'JOBTITLE' : 'DESCR'] #lookup certain columns
# Out:
#                         JOBTITLE  DEPTID                          DESCR
# 0  Facilities/Office Services II  A03031       OED-Employment Dev (031)
# 1     Assistant State's Attorney  A29045  States Attorneys Office (045)
# 2             Council Technician  A02002             City Council (002)
# 3         Police Officer Trainee  A99416        Police Department (416)
# 4                  Law Clerk SAO  A29017  States Attorneys Office (017)
# 5     Recreation Arts Instructor  A67012       R&P-Administration (012)
# 6         Operations Officer III  A90005            TRANS-Traffic (005)
# 7    EMT Firefighter Suppression  A64120          Fire Department (120)
# 8                Police Sergeant  A99160        Police Department (160)
# 9       Radio Dispatcher Sheriff  A38410         Sheriff's Office (410)

# %%
city_df[city_df['GROSS_EARNING']==city_df['GROSS_EARNING'].max()] #Lookup maximum salary
# Out:
#                    NAME         JOBTITLE  DEPTID                    DESCR  \
# 5311  Harris Jr,William  Police Sergeant  A99304  Police Department (304)
#
#                      HIRE_DT  BASE_PAY  GROSS_EARNING
# 5311  10/24/2000 12:00:00 AM  100228.0       250197.5

# %%
city_df.loc[city_df['DESCR']=='DPW-Water & Waste Water (401)'] #Lookup a certain department
# Out:
#                       NAME                        JOBTITLE  DEPTID  \
# 105              Ahsan,S M                      Engineer I  A50401
# 611        Banks,Richard A        Engineering Associate II  A50401
# 647        Barnes,Albert J     Construction Project Supv I  A50401
# 1133           Boddy,Lanny      Public Works Inspector III  A50401
# 1416         Brice,Sheri M        Public Works Inspector I  A50401
# 1574       Brown,Carroll M      Public Works Inspector III  A50401
# 1992        Cameron,Mark S                 City Planner II  A50401
# 2316       Cherigo,Matthew    Pollution Control Analyst II  A50401
# 3808    Eucare Jr,Theodore   Pollution Control Analyst III  A50401
# 4604      Gitonga,Kihoto W     Pollution Control Analyst I  A50401
# 4923      Greenberg,Warren       Public Works Inspector II  A50401
# 4971    Griffin Jr,Craig S       Public Works Inspector II  A50401
# 5127       Halford,Brian D                      Engineer I  A50401
# ...

# %%
city_df[city_df['JOBTITLE'].apply(lambda JOBTITLE: JOBTITLE[0] == 'P')].head() #Job title that starts with "P"
# Out:
#                      NAME                    JOBTITLE  DEPTID  \
# 3   Abaku,Aigbolosimuan O      Police Officer Trainee  A99416
# 8          Abdi,Ezekiel W             Police Sergeant  A99160
# 17  Abdul-Saboor,Jamillah             Printer Library  A75055
# 27     Abrahams,Brandon A              Police Officer  A99034
# 34     Abukhdeir,Tasnem M  Public Health Investigator  A65026
#
#                              DESCR                 HIRE_DT  BASE_PAY  \
# 3          Police Department (416)  04/17/2018 12:00:00 AM   50440.0
# 8          Police Department (160)  06/14/2007 12:00:00 AM   86902.0
# 17  Enoch Pratt Free Library (055)  07/27/2009 12:00:00 AM   42588.0
# 27         Police Department (034)  01/20/2015 12:00:00 AM   60732.0
# 34    HLTH-Health Department (026)  07/13/2017 12:00:00 AM   34993.0
#
#     GROSS_EARNING
# 3        11881.34
# 8       112341.17
# 17       40483.66
# 27       61097.35
# 34       29574.15

# %%
columns_to_show = ['DEPTID', 'DESCR' ]

city_df.groupby(['JOBTITLE'])[columns_to_show].describe(percentiles=[]) #Group by DeptID and Description
# Out:
#                            DEPTID                     DESCR         \
#                             count unique     top freq count unique
# JOBTITLE
# 911 Lead Operator               5      1  A64604    5     5      1
# 911 Operator                   81      1  A64604   81    81      1
# 911 Operator Supervisor         4      1  A64604    4     4      1
# ADM Coordinator                 1      1  A26001    1     1      1
# Account Executive               5      1  A91012    5     5      1
# ...                           ...    ...     ...  ...   ...    ...
# Zoning Administrator            1      1  A06041    1     1      1
# Zoning Appeals Officer          2      1  A73001    2     2      1
# Zoning Enforcement Officer      1      1  A06041    1     1      1
# Zoning Examiner I               2      1  A06041    2     2      1
# Zoning Examiner II              1      1  A06041    1     1      1
#
#
#                                                        top freq
# JOBTITLE
# ...

# %% [markdown]
# ##DATA VISUALIZATIONS##

# %%
#import necessary libaries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline

plt.style.use('bmh')

# %%
print(city_df['GROSS_EARNING'].describe()) #Look at summary statistics 
plt.figure(figsize=(9, 8))
sns.distplot(city_df['GROSS_EARNING'], color='b', bins=100, hist_kws={'alpha': 0.4}); #make a distplot
# Out:
# count     13522.000000
# mean      60729.312142
# std       36197.335957
# min           0.000000
# 25%       37509.352500
# 50%       57060.665000
# 75%       81730.975000
# max      250197.500000
# Name: GROSS_EARNING, dtype: float64
# C:\Users\nasir\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\nasir\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# C:\Users\nasir\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\nasir\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
city_df.hist() #make a histogram 
plt.show()

# %%
city_df.plot.box() #make a boxplot

# %%
sns.heatmap(dframe.corr(),fmt = ".5f") #make a heatmap

# %%
city_df.plot(x='DEPTID',y='GROSS_EARNING') #gross earning versus department ID

# %%
plt.figure(figsize=(9, 6))
plt.bar(city_df['DEPTID'],city_df['GROSS_EARNING'], color='b')
plt.xlabel("DEPTID")
plt.ylabel("GROSS_INCOME")
plt.xticks(rotation='vertical')
plt.show()
